# %%
from pyspark.sql import SparkSession

# Cell to create a spark session
spark = (
    SparkSession.builder.appName("MAST30034 ASSIGNMENT 1 DUSTIN")
    .config("spark.sql.repl.eagerEval.enabled", True) 
    .config("spark.sql.parquet.cacheMetadata", "true")
    .config("spark.sql.session.timeZone", "Etc/UTC")
    .getOrCreate()
)
# Out:
# 22/08/08 19:04:16 WARN Utils: Your hostname, DESKTOP-3ADPNV0 resolves to a loopback address: 127.0.1.1; using 172.24.5.181 instead (on interface eth0)
# 22/08/08 19:04:16 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/08/08 19:04:19 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
import pandas as pd

# %%
#Load the datasets for both taxis and nba_attendance
yellow = spark.read.parquet('../../mast30034-project-1-dustintano10/data/raw/yellow_taxi/')
green = spark.read.parquet('../../mast30034-project-1-dustintano10/data/raw/green_taxi/')
nba_attendance = pd.read_csv('../../mast30034-project-1-dustintano10/data/raw/nba_attendance_2018_2019.csv')

# %%
#preprocess the attendance dataset by removing irrelevant columns and filtering it to New York playing at Home
nba_attendance = nba_attendance.drop(nba_attendance.columns[[6,7,10]],axis = 1)
nba_attendance = nba_attendance[nba_attendance['Home/Neutral'] == 'New York Knicks']
nba_attendance
# Out:
#                  Date Start (ET)         Visitor/Neutral  PTS  \
# 6     Wed Oct 17 2018      7:30p           Atlanta Hawks  107
# 27    Sat Oct 20 2018      7:30p          Boston Celtics  103
# 67    Fri Oct 26 2018      7:30p   Golden State Warriors  128
# 89    Mon Oct 29 2018      7:30p           Brooklyn Nets   96
# 106   Wed Oct 31 2018      8:00p          Indiana Pacers  107
# 142    Mon Nov 5 2018      7:30p           Chicago Bulls  116
# 185   Sun Nov 11 2018      7:30p           Orlando Magic  115
# 250   Tue Nov 20 2018      7:30p  Portland Trail Blazers  118
# 268   Fri Nov 23 2018      7:30p    New Orleans Pelicans  109
# 329    Sat Dec 1 2018      5:00p         Milwaukee Bucks  134
# 345    Mon Dec 3 2018      7:30p      Washington Wizards  110
# 381    Sat Dec 8 2018      7:30p           Brooklyn Nets  112
# 389    Sun Dec 9 2018      7:30p       Charlotte Hornets  119
# 443   Mon Dec 17 2018      7:30p            Phoenix Suns  128
# 471   Fri Dec 21 2018      7:30p           Atlanta Hawks  114
# 496   Tue Dec 25 2018     12:00p         Milwaukee Bucks  109
# 622   Fri Jan 11 2019      7:30p          Indiana Pacers  121
# 637   Sun Jan 13 2019      1:00p      Philadelphia 76ers  108
# 690   Mon Jan 21 2019     12:30p   Oklahoma City Thunder  127
# 709   Wed Jan 23 2019      7:30p         Houston Rockets  114
# 741   Sun Jan 27 2019      7:30p              Miami Heat  106
# 757   Wed Jan 30 2019      7:30p        Dallas Mavericks  114
# 770    Fri Feb 1 2019      7:30p          Boston Celtics  113
# 786    Sun Feb 3 2019      1:00p       Memphis Grizzlies   96
# 798    Tue Feb 5 2019      7:30p         Detroit Pistons  105
# 827    Sat Feb 9 2019      7:30p         Toronto Raptors  104
# 855   Wed Feb 13 2019      7:30p      Philadelphia 76ers  126
# 877   Fri Feb 22 2019      7:30p  Minnesota Timberwolves  115
# 895   Sun Feb 24 2019      7:30p       San Antonio Spurs  118
# 907   Tue Feb 26 2019      7:30p           Orlando Magic  103
